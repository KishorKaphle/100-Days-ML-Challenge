# %% [markdown]
# # Sumarizing Book reading, Deep Learning with Python by Francois Chollet, Chapter 5 continues
#
#
# ![image.png](attachment:image.png)
#
# If you want to get an output feature map with the same spatial dimensions as the input, you can use padding. Padding consists of adding an appropriate number of rows and columns on each side of the input features map so as to make it possible to fit center convolution windows arround every input tile.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# In Conv2D layers, padding is configurable via the padding argument, which takes two values: 'valid', which means no padding (only valid window locations will be used); and 'same', which means 'pad in such a way as to have an output with the same width and height as the input. Default setting of the padding is 'valid'.

# %% [markdown]
# # Now that reading of the current book has gone at more deeper and I am feeling like I still need to know more about the mathematics and theory behind other general algorithms, I will from now read book(s) on machine learning for even better grasp fundamentally.

# %% [markdown]
# ## Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow by Aurelien Geron
#
#
# ### Types of machine learning:
#
# 1. Supervised, unsupervised, semisupervised, and reinforcement learning
#
# 2. Online or batch learning
#
#
# ### Main Challenges of Machine Learning:
#
# 1. Bad Algorithm and/or
# 2. Bad Data
#
#
# ### The Unreasonable effectiveness of data:
#
# Microsoft researchers (in 2001) published a paper where they show that with enough data for NLP, simplest to complex algoritm performed identical.
#
# ![image.png](attachment:image.png)
#
# The suprising ability of data was further highlighted by Peter Norvig et al. in a paper titled 'The Unreasonable Effectiveness of Data.'
#
# (Personal Note: this finding reminds me the power of repetition; no matter how 'dull' your mind is with repetition, practice and practice, you can perform excellently at the given task.)
#
#
# ### What is sampling bias?
# When data is unrepresentative i.e. when they are not randomly sampled, there is a high chance of sampling bias.
#
# ### Irrelevant Features:
# Garbage In Garbage Out (GIGO)
#
#
# ### Regularization:
# Limiting a model to make it simpler and reduce the risk of overfitting is called regularization.
